# %%
import os
import requests
import googlemaps
import json
from gomaps import maps_search
import time
import googlemaps
import pandas as pd
import pgeocode
import requests
import json
import re

# %%
#Function to extract place_id of user's google maps link

def get_location_from_url(url):
    # Regular expression to match latitude and longitude
    regex = r"@(-?\d+\.\d+),(-?\d+\.\d+)"
    
    # Search for latitude and longitude in the URL
    match = re.search(regex, url)
    
    if match:
        # Extract latitude and longitude from the regex match
        latitude = float(match.group(1))
        longitude = float(match.group(2))
        
        return (latitude, longitude)
    else:
        return None

# %%
import requests

def get_place_id(latitude, longitude, api_key):
    # Set up the API endpoint URL and parameters
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "location": f"{latitude},{longitude}",
        "rankby": "distance",
        "category": "restaurant",
        "key": api_key
    }
    
    # Send the API request and get the JSON response
    response = requests.get(url, params=params).json()
    
    # Check if any results were returned
    if len(response["results"]) > 0:
        # Extract the place ID from the first result
        place_id = response["results"][0]["place_id"]
        return place_id
    else:
        print("Error in get_place_id")

# %%
def extract_place_details(place_id, api_key):
    url = f'https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&key={api_key}'

    # Send a GET request to the API endpoint and retrieve the response
    response = requests.get(url)

    # Parse the JSON response and convert it to a dictionary
    result = json.loads(response.text)

    try:
        return [result["result"]]
    
    except:
        print("Error in extract_place_details")

# %%
extract_place_details("ChIJywdI5etRqEcRUVD-ycuGL6M", api_key)[0]
# Out:
# {'address_components': [{'long_name': '11',
#    'short_name': '11',
#    'types': ['street_number']},
#   {'long_name': 'Novalisstraße',
#    'short_name': 'Novalisstraße',
#    'types': ['route']},
#   {'long_name': 'Mitte',
#    'short_name': 'Mitte',
#    'types': ['sublocality_level_1', 'sublocality', 'political']},
#   {'long_name': 'Berlin',
#    'short_name': 'Berlin',
#    'types': ['locality', 'political']},
#   {'long_name': 'Kreisfreie Stadt Berlin',
#    'short_name': 'Kreisfreie Stadt Berlin',
#    'types': ['administrative_area_level_3', 'political']},
#   {'long_name': 'Berlin',
#    'short_name': 'BE',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'Germany',
#    'short_name': 'DE',
#    'types': ['country', 'political']},
#   {'long_name': '10115', 'short_name': '10115', 'types': ['postal_code']}],
#  'adr_address': 'Chausseestr. 8 Hinterhof erreichbar über: Chausseestr. 8 oder, <span class="street-address">Novalisstraße 11</span>, <span class="postal-code">10115</span> <span class="locality">Berlin</span>, <span class="country-name">Germany</span>',
#  'business_status': 'OPERATIONAL',
#  'curbside_pickup': False,
#  'current_opening_hours': {'open_now': False,
#   'periods': [{'close': {'date': '2023-03-05', 'day': 0, 'time': '2300'},
#     'open': {'date': '2023-03-05', 'day': 0, 'time': '1200'}},
#    {'close': {'date': '2023-03-06', 'day': 1, 'time': '2300'},
#     'open': {'date': '2023-03-06', 'day': 1, 'time': '1600'}},
#    {'close': {'date': '2023-03-07', 'day': 2, 'time': '2300'},
#     'open': {'date': '2023-03-07', 'day': 2, 'time': '1600'}},
#    {'close': {'date': '2023-03-08', 'day': 3, 'time': '2300'},
#     'open': {'date': '2023-03-08', 'day': 3, 'time': '1600'}},
#    {'close': {'date': '2023-03-09', 'day': 4, 'time': '2300'},
#     'open': {'date': '2023-03-09', 'day': 4, 'time': '1600'}},
#    {'close': {'date': '2023-03-03', 'day': 5, 'time': '2300'},
#     'open': {'date': '2023-03-03', 'day': 5, 'time': '1600'}},
#    {'close': {'date': '2023-03-04', 'day': 6, 'time': '2300'},
#     'open': {'date': '2023-03-04', 'day': 6, 'time': '1600'}}],
#   'weekday_text': ['Monday: 4:00\u2009–\u200911:00\u202fPM',
#    'Tuesday: 4:00\u2009–\u200911:00\u202fPM',
#    'Wednesday: 4:00\u2009–\u200911:00\u202fPM',
#    'Thursday: 4:00\u2009–\u200911:00\u202fPM',
#    'Friday: 4:00\u2009–\u200911:00\u202fPM',
#    'Saturday: 4:00\u2009–\u200911:00\u202fPM',
#    'Sunday: 12:00\u2009–\u200911:00\u202fPM']},
#  'delivery': False,
#  'dine_in': True,
#  'formatted_address': 'Chausseestr. 8 Hinterhof erreichbar über: Chausseestr. 8 oder, Novalisstraße 11, 10115 Berlin, Germany',
#  'formatted_phone_number': '030 32519422',
#  'geometry': {'location': {'lat': 52.52858310000001, 'lng': 13.3878853},
#   'viewport': {'northeast': {'lat': 52.5300668302915, 'lng': 13.3894758802915},
#    'southwest': {'lat': 52.52736886970851, 'lng': 13.3867779197085}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#  'icon_background_color': '#FF9E67',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#  'international_phone_number': '+49 30 32519422',
#  'name': 'Schnitzelei Mitte',
#  'opening_hours': {'open_now': False,
#   'periods': [{'close': {'day': 0, 'time': '2300'},
#     'open': {'day': 0, 'time': '1200'}},
#    {'close': {'day': 1, 'time': '2300'}, 'open': {'day': 1, 'time': '1600'}},
#    {'close': {'day': 2, 'time': '2300'}, 'open': {'day': 2, 'time': '1600'}},
#    {'close': {'day': 3, 'time': '2300'}, 'open': {'day': 3, 'time': '1600'}},
#    {'close': {'day': 4, 'time': '2300'}, 'open': {'day': 4, 'time': '1600'}},
#    {'close': {'day': 5, 'time': '2300'}, 'open': {'day': 5, 'time': '1600'}},
#    {'close': {'day': 6, 'time': '2300'}, 'open': {'day': 6, 'time': '1600'}}],
#   'weekday_text': ['Monday: 4:00\u2009–\u200911:00\u202fPM',
#    'Tuesday: 4:00\u2009–\u200911:00\u202fPM',
#    'Wednesday: 4:00\u2009–\u200911:00\u202fPM',
#    'Thursday: 4:00\u2009–\u200911:00\u202fPM',
#    'Friday: 4:00\u2009–\u200911:00\u202fPM',
#    'Saturday: 4:00\u2009–\u200911:00\u202fPM',
#    'Sunday: 12:00\u2009–\u200911:00\u202fPM']},
#  'photos': [{'height': 3511,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100786047769250414320">Schnitzelei Mitte</a>'],
#    'photo_reference': 'AfLeUgMOTz9hqkMV8Bo4ZKytjvvmPD8-iawoMgxTJsTh-Q4B0COenrjSitkZZueLDx-Xd2324uP09eJXWJ-dJRJyiZCgvEooLSnj8cdtW8v8rE935LQqK2NgWSkWMTCpdhvb32JLiM6EEVR3xIBNGgiO3rvN43_Nb1lMS2OBMihnC77N_OIX',
#    'width': 5267},
#   {'height': 9000,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118136077088847824298">Antonio D&#39;Isanto</a>'],
#    'photo_reference': 'AfLeUgOFACgsT00hFZS2feS9LH2v-bIfKToy989J_APr9pD5pSkXHxqcid57Jyi-dEfg7PaKAKYZziFO2N3Z6hJe0yTW0vg4mCJY-F6J_Ar0esYH4EYyBKGi1927CFcuQGyOZCVyCFnQq24QUrWst66KpT1RX_6qMEiLI0A5Swt6T7uahl8G',
#    'width': 12000},
#   {'height': 3000,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103235452363387294278">Olli David-Spickermann</a>'],
#    'photo_reference': 'AfLeUgM_48N52qccWoySC4TDuRmPb2jdhmZTd5iGxkxP_gSR1RcdK8id0YhPACaEYstDpmR4y_ZQxJ1hQ-YqYsOsZdE3Vk6dUg4RgnipCW9KjENBRcXMnGWM0WuLZxvK8iCB4aF1UIAYwTOyleuT7f5ayvQML5VOsp4ifBmZQfgvLVzc3b2a',
#    'width': 4000},
#   {'height': 9000,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111721403010434626575">Brian Hansen</a>'],
#    'photo_reference': 'AfLeUgND0z3Sb2cttcFo9gkE2wH2Lvh5ZTc8M4G0SfHFtEI2gscAfnGsUkLAz93RA09-6sG24ZNDEW1MWdPYarc5-w541_DOnLATyjcyao_nWcPj5uh1izBnphSmF0toKwCgPSu-Q8gCeDtDC46_dEgWTQ9UGvJoQqyQ-8wAb8hrWjRzekiH',
#    'width': 12000},
#   {'height': 4000,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117628712576293132016">Sven W</a>'],
#    'photo_reference': 'AfLeUgOUi7NECBhjFn0tYza5safBqoM6p_ESE4WrzZFCWzixZx4PJefz8dRJztnneAfgX84ppkAZ7ScLlltYfxnwQDlbpFqE2hFwpM3ijiOnLyaIY0FliVC86JwxAAQ2Z6NLp3QULp04Nkz9a0O8216LmSCUfMBroGFgnULqRZAWhzUTuAl0',
#    'width': 3000},
#   {'height': 1200,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118266601867054696547">Anhur Shayea</a>'],
#    'photo_reference': 'AfLeUgN7dWN-prx6qRjM-y5xoL33hIT5MinwVyrqJqtl3C8zhkkNvbSX7tbKqT17r10L7Q8BnIzzA1CmDgfOUuaWdHK2IITpuYQ7aF1PtEhC3LV4qgoxV8cUabJBmjBanaVc92oq4L4Yc_3AUOyfnW_xvfcavRw-P0RTrf9OmDD8Z98kthTC',
#    'width': 1600},
#   {'height': 1800,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106042540109770766153">Derek Mooney</a>'],
#    'photo_reference': 'AfLeUgPh9IjAnzc7btWLdYbQAhpP-z5ygzc6p6F-Yc7wDXHyJJevCyLsWrhsYHiCPenscmBzCnGj3aiqIy90W0pHYmdGYcTHPgS1io8T5K80efGQNw3SxHpBMIdsAumdDaq97P-OFm1e9LbkQGP7Ze1q4jRjM3PFA4izyIRZwjxt2XU8zj1W',
#    'width': 1440},
#   {'height': 3024,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114832239246477670218">Britta Thielen</a>'],
#    'photo_reference': 'AfLeUgPb2WzwJKBRTtI89mQT8G7cRLdlpr0gwh4EiCGaBXjh0lFc3VVc3R52PCb82Duj0_B72g1ugIiKEuun0SpHzgWq91JJj8AhZMyRTeyVEdOgXOlZhKH7qaCybV-dHSFR0z4XKIYdv36YYopDBmw8f1bfFGC3YiJFLYrIIbQhkhAhkBwm',
#    'width': 4032},
#   {'height': 4624,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116472223224332578991">Pauline Liket</a>'],
#    'photo_reference': 'AfLeUgPr4F5MeOUFwkWpaUfMjDZeKlkiSmx1XrcpdBdYN1kwTievYraBqkfNfrExK2h5jT2cIu8WGHEYJ9GyIGV4aUhIGq_574a9A_fLQ9ybfVYwMWR_5DlOu0dDOD7Xlq0XwOwvFp4I19-i-_fG5vb6-UytwzykV3UplBFxUql4TjkhNzFN',
#    'width': 3468},
#   {'height': 3024,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117972410414301865472">Chris P</a>'],
#    'photo_reference': 'AfLeUgPMit0iLe_dz3qrKZ6PsUjz7wYAV7zOuv74d_azjEyuqmF9maCUdANGpNyIh1F3xzoYqm1hnOJXzD6n3Z90i2kDD1PQlV4lf2YxQuRZbFU2Hsi9zgg8AIlnQMaLdam9YKO6HA8dOxAYCxMwb6tdYe31ZxYgXbrQvltu3MSx2OIDXRoT',
#    'width': 4032}],
#  'place_id': 'ChIJywdI5etRqEcRUVD-ycuGL6M',
#  'plus_code': {'compound_code': 'G9HQ+C5 Berlin, Germany',
#   'global_code': '9F4MG9HQ+C5'},
#  'price_level': 2,
#  'rating': 4.5,
#  'reference': 'ChIJywdI5etRqEcRUVD-ycuGL6M',
#  'reservable': True,
#  'reviews': [{'author_name': 'elventree mac',
#    'author_url': 'https://www.google.com/maps/contrib/101788176364436032208/reviews',
#    'language': 'en',
#    'original_language': 'en',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/a/AGNmyxZxaHbhGX1YIDHpqXMIuTfj8OFq6162FYs02xDM=s128-c0x00000000-cc-rp-mo-ba4',
#    'rating': 5,
#    'relative_time_description': '8 months ago',
#    'text': 'Great portions. Tap beer, friendly staff.\nThey offered us a small beer for free when we ordered.\nA bit pricey but totally worth it.\nGreat outdoor area.\n\nTips:Prefer to make a reservation. If not , it’s better to visit the place after 21.00 o clock just to make sure you find a table.',
#    'time': 1655299466,
#    'translated': False},
#   {'author_name': 'Christophe Demeyer',
#    'author_url': 'https://www.google.com/maps/contrib/116559189978925544425/reviews',
#    'language': 'en',
#    'original_language': 'en',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ACB-R5RRckPFh9afTsmOj_UJXnl0F-8r-zC9brEjAm2xWg=s128-c0x00000000-cc-rp-mo-ba4',
#    'rating': 5,
#    'relative_time_description': '3 months ago',
#    'text': "The reputation is well deserved, we had such a nice evening there. Service and food were excellent. Personnel really friendly. I do recommend, as it was one of the best schnitzel I've ever eaten. Given the fact that it is always packed you should consider book a table beforehand. We have been lucky, as we had no reservation but they did manage to grant us a table, offering a welcome beer too. Just Perfect.",
#    'time': 1667748632,
#    'translated': False},
#   {'author_name': 'Kathryn Taylor',
#    'author_url': 'https://www.google.com/maps/contrib/107856426099858698847/reviews',
#    'language': 'en',
#    'original_language': 'en',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ACB-R5TbJvIXo3mDVyMBReMjcKJfk-ECL64DJmmWUlRwAMY=s128-c0x00000000-cc-rp-mo-ba2',
#    'rating': 5,
#    'relative_time_description': '6 months ago',
#    'text': 'It was my first time (July 31) at a sit down German restaurant during my trip, so I was a bit confused on what to do. They are a lot more hands off then what I’m used to. But everything was delicious and I enjoyed my time there. I was pleasantly surprised by the welcome beer especially because I usually don’t like beer at all- but I drank the whole thing! I forgot to ask what kind it was…',
#    'time': 1661265229,
#    'translated': False},
#   {'author_name': 'Marshall Yount',
#    'author_url': 'https://www.google.com/maps/contrib/105204699250854966179/reviews',
#    'language': 'en',
#    'original_language': 'en',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ACB-R5Tqa4CN1MNcSsqjEzlwFWI79ks09QZB_90fWQRz4Q=s128-c0x00000000-cc-rp-mo-ba4',
#    'rating': 5,
#    'relative_time_description': '7 months ago',
#    'text': 'A local friend recommended this place for our last dinner for this trip to Berlin. We wanted a quality German meal, after eating all the ethnic food all week.\n\nWow, it exceeded expectations.\n\nWe got the Bavarian schnitzel, which was amazing. The regular Wiener schnitzel was good, but not in the same ballpark.\n\nGet reservations! We were lucky and arrived before the rush and were permitted to sit in the bar area.',
#    'time': 1657540603,
#    'translated': False},
#   {'author_name': 'Adam Boswell',
#    'author_url': 'https://www.google.com/maps/contrib/104995933026296885854/reviews',
#    'language': 'en',
#    'original_language': 'en',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ACB-R5Rj_DvxRCFFTbMIlLsTCubE5D5vCHgBHprW-zICknM=s128-c0x00000000-cc-rp-mo-ba5',
#    'rating': 5,
#    'relative_time_description': '6 months ago',
#    'text': "In the town of Schnitzel there are many good choices but there is only one King of Schnitzel....and it's in Mitte! This was so fantastic!! Spending a week in Berlin I was lamenting that other than currywurst I hadn't really had anything to rave about.... This is it! It's a very nice, secluded place that brings you a cold beer the moment you sit down and it just gets better from there!\n\nTake the time to come spend an hour or 2 here and enjoy the amazing food, don't forget the dessert it's equally as incredible!",
#    'time': 1661448971,
#    'translated': False}],
#  'secondary_opening_hours': [{'open_now': False,
#    'periods': [{'close': {'date': '2023-03-05', 'day': 0, 'time': '2200'},
#      'open': {'date': '2023-03-05', 'day': 0, 'time': '1200'}},
#     {'close': {'date': '2023-03-06', 'day': 1, 'time': '2200'},
#      'open': {'date': '2023-03-06', 'day': 1, 'time': '1600'}},
#     {'close': {'date': '2023-03-07', 'day': 2, 'time': '2200'},
#      'open': {'date': '2023-03-07', 'day': 2, 'time': '1600'}},
#     {'close': {'date': '2023-03-08', 'day': 3, 'time': '2200'},
#      'open': {'date': '2023-03-08', 'day': 3, 'time': '1600'}},
#     {'close': {'date': '2023-03-09', 'day': 4, 'time': '2200'},
#      'open': {'date': '2023-03-09', 'day': 4, 'time': '1600'}},
#     {'close': {'date': '2023-03-03', 'day': 5, 'time': '2200'},
#      'open': {'date': '2023-03-03', 'day': 5, 'time': '1600'}},
#     {'close': {'date': '2023-03-04', 'day': 6, 'time': '2200'},
#      'open': {'date': '2023-03-04', 'day': 6, 'time': '1600'}}],
#    'type': 'KITCHEN',
#    'weekday_text': ['Monday: 4:00\u2009–\u200910:00\u202fPM',
#     'Tuesday: 4:00\u2009–\u200910:00\u202fPM',
#     'Wednesday: 4:00\u2009–\u200910:00\u202fPM',
#     'Thursday: 4:00\u2009–\u200910:00\u202fPM',
#     'Friday: 4:00\u2009–\u200910:00\u202fPM',
#     'Saturday: 4:00\u2009–\u200910:00\u202fPM',
#     'Sunday: 12:00\u2009–\u200910:00\u202fPM']}],
#  'serves_beer': True,
#  'serves_breakfast': False,
#  'serves_brunch': False,
#  'serves_dinner': True,
#  'serves_lunch': False,
#  'serves_wine': True,
#  'takeout': True,
#  'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  'url': 'https://maps.google.com/?cid=11758765361913024593',
#  'user_ratings_total': 4138,
#  'utc_offset': 60,
#  'vicinity': 'Chausseestr. 8 Hinterhof erreichbar über: Chausseestr. 8 oder, Novalisstraße 11, Berlin',
#  'website': 'https://schnitzelei.de/mitte/',
#  'wheelchair_accessible_entrance': True}

# %%
def transform_to_df(place_details):
    user_input_details = pd.DataFrame(data = place_details)
    return user_input_details

# %%
#get user details based on google maps link
def process_user_input():
    user_input = input("please insert the goolge maps link of your favorite location: ")
    api_key = open("/Users/lukasbauerschmidt/Desktop/Ironhack/5. Final Project/2. Google API Key/key.txt").read()
    latitude, longitude = get_location_from_url(user_input)
    place_id = get_place_id(latitude, longitude, api_key)
    place_details = extract_place_details(place_id, api_key)
    user_input_details = transform_to_df(place_details)
    
    return user_input_details

# %%
process_user_input()
# Out:
# please insert the goolge maps link of your favorite location: https://www.google.com/maps/place/Papillon+Restaurant+%26+Bar/@52.5285624,13.3178458,12z/data=!3m1!5s0x47a850fe06869205:0x24233f8d666f138c!4m6!3m5!1s0x47a85104241e55e1:0x929bb8f9a337a557!8m2!3d52.5090214!4d13.3341346!16s%2Fg%2F11k3q0qvzv
#                                   address_components  \
# 0  [{'long_name': '25', 'short_name': '25', 'type...
#
#                                          adr_address business_status  \
# 0  <span class="street-address">Huttenstraße 25</...     OPERATIONAL
#
#                                current_opening_hours  \
# 0  {'open_now': True, 'periods': [{'close': {'dat...
#
#                         formatted_address  \
# 0  Huttenstraße 25, 10553 Berlin, Germany
#
#                                             geometry  \
# 0  {'location': {'lat': 52.52884969999999, 'lng':...
#
#                                                 icon icon_background_color  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...               #4B96F3
#
#                                   icon_mask_base_uri              name  ...  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...  Tante Emma Laden  ...
#
#                       place_id  \
# 0  ChIJh44tfhVRqEcR4iCZqYc38v0
#
#                                            plus_code rating  \
# 0  {'compound_code': 'G8H9+G4 Berlin, Germany', '...    4.6
#
#                      reference  \
# 0  ChIJh44tfhVRqEcR4iCZqYc38v0
#
#                                              reviews  \
# 0  [{'author_name': 'Egal Spaceship', 'author_url...
#
#                                                types  \
# 0  [grocery_or_supermarket, store, food, point_of...
#
#                                                  url user_ratings_total  \
# 0  https://maps.google.com/?cid=18298749291765244130                 13
#
#   utc_offset                 vicinity
# 0         60  Huttenstraße 25, Berlin
#
# [1 rows x 22 columns]

# %%
#get user details based on place_id searched in the following website "https://developers.google.com/maps/documentation/javascript/examples/places-placeid-finder"
def process_user_input_details():
    print("1. Please find your place_id of your favorite location using the following link: https://developers.google.com/maps/documentation/javascript/examples/places-placeid-finder")
    place_id = input("please insert the place_id of your desired location: ")
    api_key = open("/Users/lukasbauerschmidt/Desktop/Ironhack/5. Final Project/2. Google API Key/key.txt").read()
    place_details = extract_place_details(place_id, api_key)
    user_input_details = transform_to_df(place_details)
    
    return user_input_details

# %%
user_details
# Out:
#                                   address_components  \
# 0  [{'long_name': '11', 'short_name': '11', 'type...
#
#                                          adr_address business_status  \
# 0  Chausseestr. 8 Hinterhof erreichbar über: Chau...     OPERATIONAL
#
#    curbside_pickup                              current_opening_hours  \
# 0            False  {'open_now': False, 'periods': [{'close': {'da...
#
#    delivery  dine_in                                  formatted_address  \
# 0     False     True  Chausseestr. 8 Hinterhof erreichbar über: Chau...
#
#   formatted_phone_number                                           geometry  \
# 0           030 32519422  {'location': {'lat': 52.52858310000001, 'lng':...
#
#    ... serves_lunch serves_wine takeout  \
# 0  ...        False        True    True
#
#                                                types  \
# 0  [restaurant, food, point_of_interest, establis...
#
#                                                  url user_ratings_total  \
# 0  https://maps.google.com/?cid=11758765361913024593               4138
#
#   utc_offset                                           vicinity  \
# 0         60  Chausseestr. 8 Hinterhof erreichbar über: Chau...
#
#                          website  wheelchair_accessible_entrance
# 0  https://schnitzelei.de/mitte/                            True
#
# [1 rows x 39 columns]

# %%
get_coordinates(user_details)
# Out:
# (52.52858310000001, 13.3878853)

# %%
def get_coordinates(user_input_details):
    latitude = user_input_details["geometry"][0]["location"]["lat"]
    longitude = user_input_details["geometry"][0]["location"]["lng"]
    return latitude, longitude

# %%
def process_user_input_high_level(user_input_details):
    latitude, longitude = get_coordinates(user_input_details)
    
    #Google Maps API parameters
    search_string = 'restaurant'
    distance = 0.0001
    rankby=distance
    response = map_client.places_nearby(location=(latitude, longitude), keyword=search_string, radius=distance)
    
    result = response.get('results')
    
    for i, business in enumerate(result):
        latitude_hl = result[0]["geometry"]["location"]["lat"] 
        longitude_hl = result[0]["geometry"]["location"]["lng"]
        
        if latitude_hl == latitude and longitude_hl == longitude:
            high_level_result = transform_to_df(result[i])
            
            return high_level_result
        
        else:
            pass
    
    
    return

# %%
df = process_user_input_high_level(user_details)
df

# %%
df

# %%
user_details = process_user_input_details()
# Out:
# 1. Please find your place_id of your favorite location using the following link: https://developers.google.com/maps/documentation/javascript/examples/places-placeid-finder
# please insert the place_id of your desired location: ChIJywdI5etRqEcRUVD-ycuGL6M

# %%
latitude, longitude = get_coordinates(user_details)
latitude
# Out:
# 52.52858310000001

# %%
result = process_user_input_high_level(user_details, latitude, longitude)

# %%
result[0]["geometry"]["location"]["lng"]
# Out:
# 13.3879606

# %%
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': 52.526436, 'lng': 13.3879606},
#   'viewport': {'northeast': {'lat': 52.52769662989272,
#     'lng': 13.38932197989272},
#    'southwest': {'lat': 52.52499697010728, 'lng': 13.38662232010728}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#  'icon_background_color': '#FF9E67',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#  'name': 'Gambrinus',
#  'opening_hours': {'open_now': True},
#  'photos': [{'height': 1386,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110227297314101146790">Michael Ellerman</a>'],
#    'photo_reference': 'AfLeUgMTNKxA1vRgWGG6m_uTI8XnxMeCPNk0A88XrSgZdMWk3-TQm9_p4hz_hdGWn6OddGlKPWIqK-J--HeKYxLq7QYE9tR8W0c-Nm3TbS6rWXZwm885RhWxCUEwI1x5QbJBWMhDNzB4IF0rQdadQ4tFowq6ULQa2DDvzWI02WIp552J-fc',
#    'width': 1386}],
#  'place_id': 'ChIJU3egc-lRqEcRj_nx52zaxl8',
#  'plus_code': {'compound_code': 'G9GQ+H5 Berlin',
#   'global_code': '9F4MG9GQ+H5'},
#  'rating': 3.2,
#  'reference': 'ChIJU3egc-lRqEcRj_nx52zaxl8',
#  'scope': 'GOOGLE',
#  'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#  'user_ratings_total': 53,
#  'vicinity': 'Linienstraße 133, Berlin'}

# %%
df = pd.DataFrame(data=result)
df
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 52.526436, 'lng': 13.3879...
# 1     OPERATIONAL  {'location': {'lat': 52.5274428, 'lng': 13.386...
# 2     OPERATIONAL  {'location': {'lat': 52.5291035, 'lng': 13.388...
# 3     OPERATIONAL  {'location': {'lat': 52.5300558, 'lng': 13.384...
# 4     OPERATIONAL  {'location': {'lat': 52.5285831, 'lng': 13.387...
# 5     OPERATIONAL  {'location': {'lat': 52.5264943, 'lng': 13.387...
# 6     OPERATIONAL  {'location': {'lat': 52.5277295, 'lng': 13.386...
# 7     OPERATIONAL  {'location': {'lat': 52.5276532, 'lng': 13.388...
# 8     OPERATIONAL  {'location': {'lat': 52.5272492, 'lng': 13.386...
# 9     OPERATIONAL  {'location': {'lat': 52.5264427, 'lng': 13.388...
#
#                                                 icon icon_background_color  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 5  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 6  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 7  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 9  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
#                                   icon_mask_base_uri  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                 name        opening_hours  \
# 0                          Gambrinus   {'open_now': True}
# 1                       Due Fratelli   {'open_now': True}
# 2                           Petrarca   {'open_now': True}
# 3                           La Pausa   {'open_now': True}
# 4                  Schnitzelei Mitte  {'open_now': False}
# 5            PHO - Noodlebar (Mitte)   {'open_now': True}
# 6                       Hito Falafel   {'open_now': True}
# 7           Chelany-Mitte Restaurant   {'open_now': True}
# 8  La Esperanza Restaurant Tapas Bar   {'open_now': True}
# 9                       Dada Falafel   {'open_now': True}
#
#                                               photos  \
# 0  [{'height': 1386, 'html_attributions': ['<a hr...
# 1  [{'height': 2376, 'html_attributions': ['<a hr...
# 2  [{'height': 4032, 'html_attributions': ['<a hr...
# 3  [{'height': 720, 'html_attributions': ['<a hre...
# 4  [{'height': 3871, 'html_attributions': ['<a hr...
# 5  [{'height': 3024, 'html_attributions': ['<a hr...
# 6  [{'height': 720, 'html_attributions': ['<a hre...
# 7  [{'height': 720, 'html_attributions': ['<a hre...
# 8  [{'height': 1152, 'html_attributions': ['<a hr...
# 9  [{'height': 3609, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJU3egc-lRqEcRj_nx52zaxl8
# 1  ChIJj_Vp3OtRqEcRYV0ssHwRVKM
# 2  ChIJq89pru5RqEcRUvL_LoDBKcY
# 3  ChIJqVqSWeRRqEcRTB7RwSW0FF0
# 4  ChIJywdI5etRqEcRUVD-ycuGL6M
# 5  ChIJQT6Vc-lRqEcRn31gC28SamM
# 6  ChIJJdCKFdBRqEcRO5Uz93cVPWM
# 7  ChIJ32s6P-lRqEcRHxZ4L_q_2tk
# 8  ChIJ4e7xZ_lRqEcRJPrFWW0Q7c4
# 9  ChIJW9STculRqEcR6jNnlUr6nF8
#
#                                            plus_code  rating  \
# 0  {'compound_code': 'G9GQ+H5 Berlin', 'global_co...     3.2
# 1  {'compound_code': 'G9GP+XJ Berlin', 'global_co...     4.3
# 2  {'compound_code': 'G9HQ+J9 Berlin', 'global_co...     4.6
# 3  {'compound_code': 'G9JM+2P Berlin', 'global_co...     4.2
# 4  {'compound_code': 'G9HQ+C5 Berlin', 'global_co...     4.5
# 5  {'compound_code': 'G9GQ+H4 Berlin', 'global_co...     4.5
# 6  {'compound_code': 'G9HP+3P Berlin', 'global_co...     4.8
# 7  {'compound_code': 'G9HQ+3C Berlin', 'global_co...     4.6
# 8  {'compound_code': 'G9GP+VH Berlin', 'global_co...     4.7
# 9  {'compound_code': 'G9GQ+H7 Berlin', 'global_co...     4.3
#
#                      reference   scope  \
# 0  ChIJU3egc-lRqEcRj_nx52zaxl8  GOOGLE
# 1  ChIJj_Vp3OtRqEcRYV0ssHwRVKM  GOOGLE
# 2  ChIJq89pru5RqEcRUvL_LoDBKcY  GOOGLE
# 3  ChIJqVqSWeRRqEcRTB7RwSW0FF0  GOOGLE
# 4  ChIJywdI5etRqEcRUVD-ycuGL6M  GOOGLE
# 5  ChIJQT6Vc-lRqEcRn31gC28SamM  GOOGLE
# 6  ChIJJdCKFdBRqEcRO5Uz93cVPWM  GOOGLE
# 7  ChIJ32s6P-lRqEcRHxZ4L_q_2tk  GOOGLE
# 8  ChIJ4e7xZ_lRqEcRJPrFWW0Q7c4  GOOGLE
# 9  ChIJW9STculRqEcR6jNnlUr6nF8  GOOGLE
#
#                                                types  user_ratings_total  \
# 0  [restaurant, food, point_of_interest, establis...                  53
# 1  [restaurant, food, point_of_interest, establis...                 937
# 2  [restaurant, food, point_of_interest, establis...                 299
# 3  [restaurant, food, point_of_interest, establis...                 923
# 4  [restaurant, food, point_of_interest, establis...                4138
# 5  [restaurant, food, point_of_interest, establis...                2110
# 6  [restaurant, food, point_of_interest, establis...                 299
# 7  [restaurant, food, point_of_interest, establis...                1022
# 8  [cafe, night_club, bar, restaurant, food, poin...                 124
# 9  [restaurant, food, point_of_interest, establis...                1788
#
#                                             vicinity  price_level
# 0                           Linienstraße 133, Berlin          NaN
# 1                        Chausseestraße 131A, Berlin          1.0
# 2                            Novalisstraße 8, Berlin          NaN
# 3                          Chausseestraße 17, Berlin          1.0
# 4  Chausseestr. 8 Hinterhof erreichbar über: Chau...          2.0
# 5                           Linienstraße 134, Berlin          NaN
# 6                            Chauseestraße 4, Berlin          1.0
# 7                              Torstraße 221, Berlin          2.0
# 8                        Chausseestraße 131B, Berlin          NaN
# 9                           Linienstraße 132, Berlin          1.0

# %%
def transform_into_same_shape()
